# %%
a = [1,2,3]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
import cv2
im_g= cv2.imread("smallgray.png",0)
print(im_g)
# Out:
# [[187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]]

# %%
cv2.imwrite("newsmallgray.png",im_g)
# Out:
# True

# %%
im_g[0:2]
# Out:
# array([[187, 158, 104, 121, 143],
#        [198, 125, 255, 255, 147]], dtype=uint8)

# %%
im_g[0:2,2:4]
# Out:
# array([[104, 121],
#        [255, 255]], dtype=uint8)

# %%
im_g.shape
# Out:
# (3, 5)

# %%
img = cv2.imread("smallgray.png",0)
print(img)
# Out:
# [[187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]]

# %%
img[:,2:4]
# Out:
# array([[104, 121],
#        [255, 255],
#        [255,  97]], dtype=uint8)

# %%
img[2,4]
# Out:
# 182

# %%
img[3,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-ad467f0a946b> in <module>
# ----> 1 img[3,4]
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
for i in img:
    print(i)
# Out:
# [187 158 104 121 143]
# [198 125 255 255 147]
# [209 134 255  97 182]

# %%
for i in img.T:
    print(i)
# Out:
# [187 198 209]
# [158 125 134]
# [104 255 255]
# [121 255  97]
# [143 147 182]

# %%
for i in img.flat:
    print(i)
# Out:
# 187
# 158
# 104
# 121
# 143
# 198
# 125
# 255
# 255
# 147
# 209
# 134
# 255
# 97
# 182

# %%
for i in img:
    for j in i:
        print(j)
# Out:
# 187
# 158
# 104
# 121
# 143
# 198
# 125
# 255
# 255
# 147
# 209
# 134
# 255
# 97
# 182
