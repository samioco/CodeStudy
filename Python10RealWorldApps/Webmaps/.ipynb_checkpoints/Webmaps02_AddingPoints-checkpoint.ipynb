# %%
print("""
tiles = "Mapbox Bright"
Please use this instead:
tiles = "Stamen Terrain"
""")
# Out:
# tiles = "Mapbox Bright"
# Please use this instead:
# tiles = "Stamen Terrain"

# %%
import folium

# %%
map = folium.Map(location=[47.620601, -122.329741], zoom_start=15, tiles = "Stamen Terrain")

# %%
map.save("Map2.html")
