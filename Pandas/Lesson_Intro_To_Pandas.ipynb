# %%
# !pip install pandas

# %%
import pandas

# %%
df1 = pandas.DataFrame([[1,2,3],[10,20,30]])

# %%
df1
# Out:
#     0   1   2
# 0   1   2   3
# 1  10  20  30

# %%
df1 = pandas.DataFrame([[1,2,3],[10,20,30]],columns=["Price","Age","Value"])

# %%
df1
# Out:
#    Price  Age  Value
# 0      1    2      3
# 1     10   20     30

# %%
df1 = pandas.DataFrame([[1,2,3],[10,20,30]],columns=["Price","Age","Value"],index=["First","Second"])

# %%
df1
# Out:
#         Price  Age  Value
# First       1    2      3
# Second     10   20     30

# %%
df2 = pandas.DataFrame([{"Name":"John"},{"Name":"Jack"}])
df2
# Out:
#    Name
# 0  John
# 1  Jack

# %%
df2 = pandas.DataFrame([{"Name":"John","Surname":"Wick"},{"Name":"Jack"}])
df2
# Out:
#    Name Surname
# 0  John    Wick
# 1  Jack     NaN

# %%
df2 = pandas.DataFrame([{"Name":"John","Surname":"Wick"},{"Name":"Jack","Surname":""}])
df2
