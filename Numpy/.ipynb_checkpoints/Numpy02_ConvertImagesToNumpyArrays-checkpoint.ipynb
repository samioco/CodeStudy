# %%
#pip install opencv-python
import cv2

# %%
#linux debugging
print("""
sudo apt-get install libqt4-dev
cmake -D WITH_QT=ON ..
make
sudo make install

#alternate:
sudo apt-get install libopencv-*
pip install opencv-python

import cv2
""")
# Out:
# sudo apt-get install libqt4-dev
# cmake -D WITH_QT=ON ..
# make
# sudo make install
#
# #alternate:
# sudo apt-get install libopencv-*
# pip install opencv-python
#
# import cv2

# %%
import os
os.listdir()
# Out:
# ['smallgray.png',
#  'Numpy01_Intro.html',
#  'Numpy02_.ipynb',
#  '.ipynb_checkpoints',
#  'Numpy01_Intro.ipynb']

# %%
im_g0 = cv2.imread("smallgray.png",0)
#0 for grayscale
#1 for BGR (blue green red)
print(im_g0)
# Out:
# [[187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]]

# %%
im_g1= cv2.imread("smallgray.png",1)
print(im_g1)
# Out:
# [[[187 187 187]
#   [158 158 158]
#   [104 104 104]
#   [121 121 121]
#   [143 143 143]]
#
#  [[198 198 198]
#   [125 125 125]
#   [255 255 255]
#   [255 255 255]
#   [147 147 147]]
#
#  [[209 209 209]
#   [134 134 134]
#   [255 255 255]
#   [ 97  97  97]
#   [182 182 182]]]

# %%
cv2.imwrite("newsmallgray.png", im_g1)
# Out:
# True

# %%
os.listdir()
# Out:
# ['smallgray.png',
#  'Numpy01_Intro.html',
#  'Numpy02_.ipynb',
#  'newsmallgray.png',
#  '.ipynb_checkpoints',
#  'Numpy01_Intro.ipynb']

# %%
#file exists!
